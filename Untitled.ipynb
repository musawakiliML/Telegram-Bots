# %%
import pyowm

# %%
API_KEY = '1f044a70f0d3ab8c1377ff9aec5827c3'

# %%
def city_name(place):
    
    open_weather_map = pyowm.OWM(API_KEY)
    open_weather_manager = open_weather_map.weather_manager()
    weather_observation = open_weather_manager.weather_at_place(place)
    weather = weather_observation.weather
    
    temperature = weather.temperature(unit='fahrenheit')['temp']
    
    return [temperature]

city_name("Bauchi")

# %%
import telegram

# %%
bot = telegram.Bot(token = '900246962:AAEYa-hb4z2sZfqzbB2eNSKBLozBB_qzK70')
print(bot.get_me())

# %%
from telegram.ext import Updater, MessageHandler, CommandHandler, Filters
import logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                   level = logging.INFO)

token = '900246962:AAEYa-hb4z2sZfqzbB2eNSKBLozBB_qzK70'
updater = Updater(token, use_context=True)
dispatcher = updater.dispatcher


def start(update, context):
    context.bot.send_message(chat_id = update.effective_chat.id, 
                             text="Hello i am a weather chat bot.")
    

start_handler = CommandHandler('start', start)
dispatcher.add_handler(start_handler)


def echo(update, context):
    context.bot.send_message(chat_id=update.effective_chat.id,
                            text=update.message.text)
    
echo_handler = MessageHandler(Filters.text &(~Filters.command), echo)
dispatcher.add_handler(echo_handler)


def caps(update, context):
    text_caps = ''.join(contex.args).upper()
    context.bot.send_message(chat_id=update.effective_chat.id, text=text_caps)

caps_handler = CommandHandler('caps',caps)
dispatcher.add_handler(caps_handler)

updater.start_polling()
#updater.idle()
#updater.stop()
# Out:
# 2021-02-03 00:47:00,508 - apscheduler.scheduler - INFO - Scheduler started
# 2021-02-03 00:47:01,488 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2021-02-03 00:47:01,490 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/MusaML/.local/lib/python3.8/site-packages/telegram/ext/updater.py", line 465, in _network_loop_retry
#     if not action_cb():
#   File "/Users/MusaML/.local/lib/python3.8/site-packages/telegram/ext/updater.py", line 416, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "<decorator-gen-147>", line 2, in get_updates
#   File "/Users/MusaML/.local/lib/python3.8/site-packages/telegram/bot.py", line 135, in decorator
#     result = func(*args, **kwargs)
# ...

# %%
updater.stop()
# Out:
# 2021-02-03 00:46:50,541 - apscheduler.scheduler - INFO - Scheduler has been shut down
# 2021-02-03 00:46:57,154 - telegram.ext.updater - ERROR - Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# 2021-02-03 00:46:57,156 - telegram.ext.dispatcher - ERROR - No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/MusaML/.local/lib/python3.8/site-packages/telegram/ext/updater.py", line 465, in _network_loop_retry
#     if not action_cb():
#   File "/Users/MusaML/.local/lib/python3.8/site-packages/telegram/ext/updater.py", line 416, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "<decorator-gen-147>", line 2, in get_updates
#   File "/Users/MusaML/.local/lib/python3.8/site-packages/telegram/bot.py", line 135, in decorator
#     result = func(*args, **kwargs)
# ...

# %%
updater.update_queue()
